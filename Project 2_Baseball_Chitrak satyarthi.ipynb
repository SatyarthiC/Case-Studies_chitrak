# %%
import mysql.connector

# %%
cnx = mysql.connector.connect(
   host="127.0.0.1",
   port=3306,
   user="root",
   passwd="2@Satyarthi"
)

# %%
import pandas as pd
import numpy as np
con=mysql.connector.connect(
host="localhost",
port=3306,
user="root",
password="2@Satyarthi",
database="baseball")

df=pd.read_sql_query("Select * from base",con)
df
df.head(35)
# Out:
#     Walks  Run      AB    Hits   2b  3b   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95.0  724  5575.0  1497.0  300  42  139  383   973  104  641  601  3.73
# 1    83.0  696  5467.0  1349.0  277  44  156  439  1264   70  700  653  4.07
# 2    81.0  669  5439.0  1395.0  303  29  141  533  1157   86  640  584  3.67
# 3    76.0  622  5533.0  1381.0  260  27  136  404  1231   68  701  643  3.98
# 4    74.0  689  5605.0  1515.0  289  49  151  455  1259   83  803  746  4.64
# 5    93.0  891  5509.0  1480.0  308  17  232  570  1151   88  670  609  3.80
# 6    87.0  764  5567.0  1397.0  272  19  212  554  1227   63  698  652  4.03
# 7    81.0  713  5485.0  1370.0  246  20  217  418  1331   44  693  646  4.05
# 8    80.0  644  5485.0  1383.0  278  32  167  436  1310   87  642  604  3.74
# 9    78.0  748  5640.0  1495.0  294  33  161  478  1148   71  753  694  4.31
# 10   88.0  751  5511.0  1419.0  279  32  172  503  1233  101  733  680  4.24
# ...

# %%
def Q(sql):
    res=pd.read_sql_query(sql,con)
    return (res)

# %%
df=pd.read_csv("C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/base.csv")
print(df)
# Out:
#      95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2  \
# 0    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 1    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 2    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 3    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 4    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 5    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 6    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 7    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 8    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 9    88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 10   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df=pd.read_sql_query("Select * from base",con)
df
df.head(35)
# Out:
#     Walks  Run      AB    Hits   2b  3b   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95.0  724  5575.0  1497.0  300  42  139  383   973  104  641  601  3.73
# 1    83.0  696  5467.0  1349.0  277  44  156  439  1264   70  700  653  4.07
# 2    81.0  669  5439.0  1395.0  303  29  141  533  1157   86  640  584  3.67
# 3    76.0  622  5533.0  1381.0  260  27  136  404  1231   68  701  643  3.98
# 4    74.0  689  5605.0  1515.0  289  49  151  455  1259   83  803  746  4.64
# 5    93.0  891  5509.0  1480.0  308  17  232  570  1151   88  670  609  3.80
# 6    87.0  764  5567.0  1397.0  272  19  212  554  1227   63  698  652  4.03
# 7    81.0  713  5485.0  1370.0  246  20  217  418  1331   44  693  646  4.05
# 8    80.0  644  5485.0  1383.0  278  32  167  436  1310   87  642  604  3.74
# 9    78.0  748  5640.0  1495.0  294  33  161  478  1148   71  753  694  4.31
# 10   88.0  751  5511.0  1419.0  279  32  172  503  1233  101  733  680  4.24
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show()

# %%
df.skew()
# Out:
# Walks    0.047089
# Run      1.200786
# AB       0.183437
# Hits     0.670254
# 2b      -0.230650
# 3b       0.129502
# HR       0.516441
# BB       0.158498
# SO      -0.156065
# SB       0.479893
# RA       0.045734
# ER       0.058710
# ERA      0.053331
# CG       0.736845
# SHO      0.565790
# SV       0.657524
# E        0.890132
# dtype: float64

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_sql_query("Select * from base",con)
df
list(df.columns)
# Out:
# ['Walks',
#  'Run',
#  'AB',
#  'Hits',
#  '2b',
#  '3b',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
df['RD']=df['Run']-df['RA']

# %%
plt.scatter(x=df.Run, y=df.Walks)

# %%
import statsmodels.api as sm
x=sm.add_constant(df['Run'])
y=df['Walks']
x.head(35)
# Out:
#     const  Run
# 0     1.0  724
# 1     1.0  696
# 2     1.0  669
# 3     1.0  622
# 4     1.0  689
# 5     1.0  891
# 6     1.0  764
# 7     1.0  713
# 8     1.0  644
# 9     1.0  748
# 10    1.0  751
# 11    1.0  729
# 12    1.0  661
# 13    1.0  656
# 14    1.0  694
# 15    1.0  647
# 16    1.0  697
# 17    1.0  689
# 18    1.0  655
# 19    1.0  640
# 20    1.0  683
# 21    1.0  703
# 22    1.0  613
# 23    1.0  573
# 24    1.0  626
# 25    1.0  667
# 26    1.0  696
# 27    1.0  720
# 28    1.0  650
# 29    1.0  737

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

# %%
df_lm1=sm.OLS(train_y,train_x).fit()

# %%
print (df_lm1.params)
# Out:
# const    13.360281
# Run       0.099012
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['AB'])
y=df['Walks']
x.head(35)
# Out:
#     const      AB
# 0     1.0  5575.0
# 1     1.0  5467.0
# 2     1.0  5439.0
# 3     1.0  5533.0
# 4     1.0  5605.0
# 5     1.0  5509.0
# 6     1.0  5567.0
# 7     1.0  5485.0
# 8     1.0  5485.0
# 9     1.0  5640.0
# 10    1.0  5511.0
# 11    1.0  5459.0
# 12    1.0  5417.0
# 13    1.0  5544.0
# 14    1.0  5600.0
# 15    1.0  5484.0
# 16    1.0  5631.0
# 17    1.0  5491.0
# 18    1.0  5480.0
# 19    1.0  5571.0
# 20    1.0  5527.0
# 21    1.0  5428.0
# 22    1.0  5463.0
# 23    1.0  5420.0
# 24    1.0  5529.0
# 25    1.0  5385.0
# 26    1.0  5565.0
# 27    1.0  5649.0
# 28    1.0  5457.0
# 29    1.0  5572.0

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

# %%
df_lm2=sm.OLS(train_y,train_x).fit()

# %%
print (df_lm2.params)
# Out:
# const    152.276663
# AB        -0.012962
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['Hits'])
y=df['Walks']
x.head(35)
# Out:
#     const    Hits
# 0     1.0  1497.0
# 1     1.0  1349.0
# 2     1.0  1395.0
# 3     1.0  1381.0
# 4     1.0  1515.0
# 5     1.0  1480.0
# 6     1.0  1397.0
# 7     1.0  1370.0
# 8     1.0  1383.0
# 9     1.0  1495.0
# 10    1.0  1419.0
# 11    1.0  1363.0
# 12    1.0  1331.0
# 13    1.0  1379.0
# 14    1.0  1405.0
# 15    1.0  1386.0
# 16    1.0  1462.0
# 17    1.0  1341.0
# 18    1.0  1378.0
# 19    1.0  1382.0
# 20    1.0  1351.0
# 21    1.0  1363.0
# 22    1.0  1420.0
# 23    1.0  1361.0
# 24    1.0  1374.0
# 25    1.0  1346.0
# 26    1.0  1486.0
# 27    1.0  1494.0
# 28    1.0  1324.0
# 29    1.0  1479.0

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm3=sm.OLS(train_y,train_x).fit()

print (df_lm3.params)
# Out:
# const    95.507905
# Hits     -0.010508
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['2b'])
y=df['Walks']
x.head(35)
# Out:
#     const   2b
# 0     1.0  300
# 1     1.0  277
# 2     1.0  303
# 3     1.0  260
# 4     1.0  289
# 5     1.0  308
# 6     1.0  272
# 7     1.0  246
# 8     1.0  278
# 9     1.0  294
# 10    1.0  279
# 11    1.0  278
# 12    1.0  243
# 13    1.0  262
# 14    1.0  277
# 15    1.0  288
# 16    1.0  292
# 17    1.0  272
# 18    1.0  274
# 19    1.0  257
# 20    1.0  295
# 21    1.0  265
# 22    1.0  236
# 23    1.0  251
# 24    1.0  272
# 25    1.0  263
# 26    1.0  288
# 27    1.0  289
# 28    1.0  260
# 29    1.0  274

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm4=sm.OLS(train_y,train_x).fit()

print (df_lm4.params)
# Out:
# const   -1.039956
# 2b       0.298157
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['3b'])
y=df['Walks']
x.head(35)
# Out:
#     const  3b
# 0     1.0  42
# 1     1.0  44
# 2     1.0  29
# 3     1.0  27
# 4     1.0  49
# 5     1.0  17
# 6     1.0  19
# 7     1.0  20
# 8     1.0  32
# 9     1.0  33
# 10    1.0  32
# 11    1.0  26
# 12    1.0  21
# 13    1.0  22
# 14    1.0  46
# 15    1.0  39
# 16    1.0  27
# 17    1.0  30
# 18    1.0  34
# 19    1.0  27
# 20    1.0  17
# 21    1.0  13
# 22    1.0  40
# 23    1.0  18
# 24    1.0  37
# 25    1.0  26
# 26    1.0  39
# 27    1.0  48
# 28    1.0  36
# 29    1.0  49

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm5=sm.OLS(train_y,train_x).fit()

print (df_lm5.params)
# Out:
# const    88.133879
# 3b       -0.228551
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['HR'])
y=df['Walks']
x.head(35)
# Out:
#     const   HR
# 0     1.0  139
# 1     1.0  156
# 2     1.0  141
# 3     1.0  136
# 4     1.0  151
# 5     1.0  232
# 6     1.0  212
# 7     1.0  217
# 8     1.0  167
# 9     1.0  161
# 10    1.0  172
# 11    1.0  230
# 12    1.0  176
# 13    1.0  198
# 14    1.0  146
# 15    1.0  137
# 16    1.0  140
# 17    1.0  171
# 18    1.0  145
# 19    1.0  167
# 20    1.0  177
# 21    1.0  177
# 22    1.0  120
# 23    1.0  100
# 24    1.0  130
# 25    1.0  187
# 26    1.0  136
# 27    1.0  154
# 28    1.0  148
# 29    1.0  186

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm6=sm.OLS(train_y,train_x).fit()

print (df_lm6.params)
# Out:
# const    64.686907
# HR        0.100185
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['BB'])
y=df['Walks']
x.head(35)
# Out:
#     const   BB
# 0     1.0  383
# 1     1.0  439
# 2     1.0  533
# 3     1.0  404
# 4     1.0  455
# 5     1.0  570
# 6     1.0  554
# 7     1.0  418
# 8     1.0  436
# 9     1.0  478
# 10    1.0  503
# 11    1.0  486
# 12    1.0  435
# 13    1.0  478
# 14    1.0  475
# 15    1.0  506
# 16    1.0  461
# 17    1.0  567
# 18    1.0  412
# 19    1.0  496
# 20    1.0  488
# 21    1.0  539
# 22    1.0  375
# 23    1.0  471
# 24    1.0  387
# 25    1.0  563
# 26    1.0  457
# 27    1.0  490
# 28    1.0  426
# 29    1.0  388

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm7=sm.OLS(train_y,train_x).fit()

print (df_lm7.params)
# Out:
# const    39.693937
# BB        0.087839
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['SO'])
y=df['Walks']
x.head(35)
# Out:
#     const    SO
# 0     1.0   973
# 1     1.0  1264
# 2     1.0  1157
# 3     1.0  1231
# 4     1.0  1259
# 5     1.0  1151
# 6     1.0  1227
# 7     1.0  1331
# 8     1.0  1310
# 9     1.0  1148
# 10    1.0  1233
# 11    1.0  1392
# 12    1.0  1150
# 13    1.0  1336
# 14    1.0  1119
# 15    1.0  1267
# 16    1.0  1322
# 17    1.0  1518
# 18    1.0  1299
# 19    1.0  1255
# 20    1.0  1290
# 21    1.0  1344
# 22    1.0  1150
# 23    1.0  1107
# 24    1.0  1274
# 25    1.0  1258
# 26    1.0  1159
# 27    1.0  1312
# 28    1.0  1327
# 29    1.0  1283

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm8=sm.OLS(train_y,train_x).fit()

print (df_lm8.params)
# Out:
# const    51.300256
# SO        0.023456
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['SB'])
y=df['Walks']
x.head(35)
# Out:
#     const   SB
# 0     1.0  104
# 1     1.0   70
# 2     1.0   86
# 3     1.0   68
# 4     1.0   83
# 5     1.0   88
# 6     1.0   63
# 7     1.0   44
# 8     1.0   87
# 9     1.0   71
# 10    1.0  101
# 11    1.0  121
# 12    1.0   52
# 13    1.0   69
# 14    1.0   78
# 15    1.0   69
# 16    1.0   98
# 17    1.0   95
# 18    1.0   84
# 19    1.0  134
# 20    1.0   51
# 21    1.0   57
# 22    1.0  112
# 23    1.0   69
# 24    1.0   88
# 25    1.0   59
# 26    1.0   93
# 27    1.0  132
# 28    1.0   82
# 29    1.0   97

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm9=sm.OLS(train_y,train_x).fit()

print (df_lm9.params)
# Out:
# const    88.079665
# SB       -0.085323
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['RA'])
y=df['Walks']
x.head(35)
# Out:
#     const   RA
# 0     1.0  641
# 1     1.0  700
# 2     1.0  640
# 3     1.0  701
# 4     1.0  803
# 5     1.0  670
# 6     1.0  698
# 7     1.0  693
# 8     1.0  642
# 9     1.0  753
# 10    1.0  733
# 11    1.0  618
# 12    1.0  675
# 13    1.0  726
# 14    1.0  729
# 15    1.0  525
# 16    1.0  596
# 17    1.0  608
# 18    1.0  737
# 19    1.0  754
# 20    1.0  613
# 21    1.0  635
# 22    1.0  678
# 23    1.0  760
# 24    1.0  809
# 25    1.0  595
# 26    1.0  627
# 27    1.0  713
# 28    1.0  731
# 29    1.0  844

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm10=sm.OLS(train_y,train_x).fit()

print (df_lm10.params)
# Out:
# const    162.958673
# RA        -0.119770
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['ER'])
y=df['Walks']
x.head(35)
# Out:
#     const   ER
# 0     1.0  601
# 1     1.0  653
# 2     1.0  584
# 3     1.0  643
# 4     1.0  746
# 5     1.0  609
# 6     1.0  652
# 7     1.0  646
# 8     1.0  604
# 9     1.0  694
# 10    1.0  680
# 11    1.0  572
# 12    1.0  630
# 13    1.0  677
# 14    1.0  664
# 15    1.0  478
# 16    1.0  532
# 17    1.0  546
# 18    1.0  682
# 19    1.0  700
# 20    1.0  557
# 21    1.0  577
# 22    1.0  638
# 23    1.0  698
# 24    1.0  749
# 25    1.0  553
# 26    1.0  597
# 27    1.0  659
# 28    1.0  655
# 29    1.0  799

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm11=sm.OLS(train_y,train_x).fit()

print (df_lm11.params)
# Out:
# const    157.138232
# ER        -0.120444
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['ER'])
y=df['Walks']
x.head(35)
# Out:
#     const   ER
# 0     1.0  601
# 1     1.0  653
# 2     1.0  584
# 3     1.0  643
# 4     1.0  746
# 5     1.0  609
# 6     1.0  652
# 7     1.0  646
# 8     1.0  604
# 9     1.0  694
# 10    1.0  680
# 11    1.0  572
# 12    1.0  630
# 13    1.0  677
# 14    1.0  664
# 15    1.0  478
# 16    1.0  532
# 17    1.0  546
# 18    1.0  682
# 19    1.0  700
# 20    1.0  557
# 21    1.0  577
# 22    1.0  638
# 23    1.0  698
# 24    1.0  749
# 25    1.0  553
# 26    1.0  597
# 27    1.0  659
# 28    1.0  655
# 29    1.0  799

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm12=sm.OLS(train_y,train_x).fit()

print (df_lm12.params)
# Out:
# const    157.138232
# ER        -0.120444
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['ERA'])
y=df['Walks']
x.head(35)
# Out:
#     const   ERA
# 0     1.0  3.73
# 1     1.0  4.07
# 2     1.0  3.67
# 3     1.0  3.98
# 4     1.0  4.64
# 5     1.0  3.80
# 6     1.0  4.03
# 7     1.0  4.05
# 8     1.0  3.74
# 9     1.0  4.31
# 10    1.0  4.24
# 11    1.0  3.57
# 12    1.0  3.94
# 13    1.0  4.16
# 14    1.0  4.14
# 15    1.0  2.94
# 16    1.0  3.21
# 17    1.0  3.36
# 18    1.0  4.28
# 19    1.0  4.33
# 20    1.0  3.43
# 21    1.0  3.62
# 22    1.0  4.02
# 23    1.0  4.41
# 24    1.0  4.69
# 25    1.0  3.44
# 26    1.0  3.72
# 27    1.0  4.04
# 28    1.0  4.09
# 29    1.0  5.04

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm13=sm.OLS(train_y,train_x).fit()

print (df_lm13.params)
# Out:
# const    154.841292
# ERA      -18.772483
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['CG'])
y=df['Walks']
x.head(35)
# Out:
#     const  CG
# 0     1.0   2
# 1     1.0   2
# 2     1.0  11
# 3     1.0   7
# 4     1.0   7
# 5     1.0   7
# 6     1.0   3
# 7     1.0   0
# 8     1.0   1
# 9     1.0   3
# 10    1.0   5
# 11    1.0   5
# 12    1.0   2
# 13    1.0   6
# 14    1.0   5
# 15    1.0   1
# 16    1.0   0
# 17    1.0   6
# 18    1.0   1
# 19    1.0   2
# 20    1.0   1
# 21    1.0   4
# 22    1.0   0
# 23    1.0   3
# 24    1.0   1
# 25    1.0   6
# 26    1.0   7
# 27    1.0   1
# 28    1.0   1
# 29    1.0   4

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm14=sm.OLS(train_y,train_x).fit()

print (df_lm14.params)
# Out:
# const    80.553093
# CG        0.073407
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['SHO'])
y=df['Walks']
x.head(35)
# Out:
#     const  SHO
# 0     1.0    8
# 1     1.0   12
# 2     1.0   10
# 3     1.0    9
# 4     1.0   12
# 5     1.0   10
# 6     1.0    4
# 7     1.0   10
# 8     1.0   12
# 9     1.0   10
# 10    1.0    9
# 11    1.0   13
# 12    1.0   12
# 13    1.0   12
# 14    1.0   15
# 15    1.0   15
# 16    1.0   13
# 17    1.0   21
# 18    1.0    7
# 19    1.0    8
# 20    1.0   14
# 21    1.0   13
# 22    1.0   12
# 23    1.0   10
# 24    1.0    7
# 25    1.0   21
# 26    1.0   18
# 27    1.0   12
# 28    1.0    6
# 29    1.0    4

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm15=sm.OLS(train_y,train_x).fit()

print (df_lm15.params)
# Out:
# const    65.976102
# SHO       1.312080
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['SV'])
y=df['Walks']
x.head(35)
# Out:
#     const  SV
# 0     1.0  56
# 1     1.0  45
# 2     1.0  38
# 3     1.0  37
# 4     1.0  35
# 5     1.0  34
# 6     1.0  48
# 7     1.0  43
# 8     1.0  60
# 9     1.0  40
# 10    1.0  45
# 11    1.0  39
# 12    1.0  46
# 13    1.0  45
# 14    1.0  28
# 15    1.0  62
# 16    1.0  54
# 17    1.0  48
# 18    1.0  40
# 19    1.0  35
# 20    1.0  50
# 21    1.0  41
# 22    1.0  35
# 23    1.0  44
# 24    1.0  35
# 25    1.0  47
# 26    1.0  41
# 27    1.0  44
# 28    1.0  41
# 29    1.0  36

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm16=sm.OLS(train_y,train_x).fit()

print (df_lm16.params)
# Out:
# const    37.152691
# SV        1.002235
# dtype: float64

# %%
import statsmodels.api as sm
x=sm.add_constant(df['E'])
y=df['Walks']
x.head(35)
# Out:
#     const    E
# 0     1.0   88
# 1     1.0   86
# 2     1.0   79
# 3     1.0  101
# 4     1.0   86
# 5     1.0   88
# 6     1.0   93
# 7     1.0   77
# 8     1.0   95
# 9     1.0   97
# 10    1.0  119
# 11    1.0   85
# 12    1.0   93
# 13    1.0   94
# 14    1.0  126
# 15    1.0   96
# 16    1.0  122
# 17    1.0  111
# 18    1.0  116
# 19    1.0   90
# 20    1.0   88
# 21    1.0   90
# 22    1.0   77
# 23    1.0   90
# 24    1.0  117
# 25    1.0   75
# 26    1.0   78
# 27    1.0   86
# 28    1.0   92
# 29    1.0   95

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8,random_state=100)

df_lm17=sm.OLS(train_y,train_x).fit()

print (df_lm17.params)
# Out:
# const    85.343899
# E        -0.047751
# dtype: float64
